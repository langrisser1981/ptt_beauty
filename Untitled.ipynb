# %%
import requests

def get_web_page(url):
    resp = requests.get(
        url=url,
        cookies={'over18':'1'}
    )
    
    if resp.status_code != 200:
        print('error', resp.url)
        return None
    else:
        return resp.text

# %%
if __name__ == '__main__':
    page = get_web_page('https://www.ptt.cc/bbs/Beauty/index.html')
    if page:
        print(page)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Beauty 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Beauty/index.html"><span class="board-label">看板 </span>Beauty</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
import time

date = time.strftime('%m/%d').lstrip('0')
print(date)
# Out:
# 9/10

# %%
from bs4 import BeautifulSoup

def get_articles(dom, date):
    soup = BeautifulSoup(page, 'html.parser')
    #print(soup.prettify())
    
    articles = []
    divs = soup.find_all('div', 'r-ent')
    for div in divs:
        date = '{:>5s}'.format(date)
        if str(div.find('div', 'date').string) == date:
            push_count = 0
            if div.find('div', 'nrec').string:
                try:
                    push_count = int(div.find('div', 'nrec').string)
                except ValueError:
                    pass
            
            if div.find('a'):
                href = div.find('a').get('href')
                title = div.find('a').string
                
                articles.append({
                    'title':title,
                    'href':href,
                    'push_count':push_count
                })

    return articles

# %%
if page:
    articles = get_articles(page, date)
    for post in articles:
        print(post)
# Out:
# {'title': '[正妹] 手錶', 'href': '/bbs/Beauty/M.1536514821.A.43D.html', 'push_count': 10}
# {'title': '[神人] 朋友玩遊戲認識的', 'href': '/bbs/Beauty/M.1536523358.A.C22.html', 'push_count': 32}
# {'title': '[正妹] 一張', 'href': '/bbs/Beauty/M.1536536328.A.B60.html', 'push_count': 3}
# {'title': '[正妹] 嚇到吃吃', 'href': '/bbs/Beauty/M.1536551061.A.C75.html', 'push_count': 4}
# {'title': '[神人] 似乎是大陸人?', 'href': '/bbs/Beauty/M.1536562605.A.2A6.html', 'push_count': 0}
# {'title': '[正妹] 泳裝/健身', 'href': '/bbs/Beauty/M.1536566188.A.1FA.html', 'push_count': 6}
# {'title': '[正妹] 桜井玲香(圖多)', 'href': '/bbs/Beauty/M.1536566268.A.B94.html', 'push_count': 26}
# {'title': '[帥哥] 認真的落腮鬍男人', 'href': '/bbs/Beauty/M.1536580377.A.CBF.html', 'push_count': 0}
# {'title': '[正妹] 墨鏡靚女', 'href': '/bbs/Beauty/M.1536584736.A.278.html', 'push_count': 0}
# {'title': '[正妹] AKB48 Team TP 董子瑄', 'href': '/bbs/Beauty/M.1536585108.A.D75.html', 'push_count': 5}
# ...
